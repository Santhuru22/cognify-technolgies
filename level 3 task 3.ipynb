# %% [markdown]
# # Level 03 - Task 03 - Data Visualization
# ### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Choose Dataset from Local Directory

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d02162ea-1b66-4b12-8a59-fef6bdf66913" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d02162ea-1b66-4b12-8a59-fef6bdf66913">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ###  Data Visualization

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df["Aggregate rating"], bins=20, kde=True, color='blue')
plt.xlabel("Aggregate Rating")
plt.ylabel("Frequency")
plt.title("Distribution of Ratings")
plt.show()

avg_rating_by_cuisine = cuisine_rating.sort_values(by="Aggregate rating", ascending=False).head(10)
plt.figure(figsize=(10, 6))
sns.barplot(y=avg_rating_by_cuisine["Cuisines"], x=avg_rating_by_cuisine["Aggregate rating"], palette="magma")
plt.xlabel("Average Rating")
plt.ylabel("Cuisines")
plt.title("Top 10 Cuisines by Average Rating")
plt.show()

city_rating = df.groupby("City")["Aggregate rating"].mean().reset_index()
top_cities = city_rating.sort_values(by="Aggregate rating", ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(y=top_cities["City"], x=top_cities["Aggregate rating"], palette="plasma")
plt.xlabel("Average Rating")
plt.ylabel("City")
plt.title("Top 10 Cities by Average Rating")
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x=df["Votes"], y=df["Aggregate rating"], alpha=0.6, color='purple')
plt.xlabel("Number of Votes")
plt.ylabel("Aggregate Rating")
plt.title("Votes vs. Aggregate Rating")
plt.show()
# Out:
# <ipython-input-21-c72e3857741b>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=avg_rating_by_cuisine["Cuisines"], x=avg_rating_by_cuisine["Aggregate rating"], palette="magma")
# <ipython-input-21-c72e3857741b>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_cities["City"], x=top_cities["Aggregate rating"], palette="plasma")
